# %%
import pandas as pd
import numpy as np

# %%
# %load get_data.py
def get_data() :
    
    import pandas as pd
    
    csv_beer = pd.read_csv("/home/grimoire/Projects/BeerRatings/rating_update.csv")
    beer_ratings = pd.DataFrame(csv_beer)
    
    return beer_ratings

# %%
ratings = get_data()

# %%
test = ratings.copy()

# %%
test.keys()
# Out:
# Index(['brewery_id', 'brewery_name', 'review_time', 'review_overall',
#        'review_aroma', 'review_appearance', 'review_profilename', 'beer_style',
#        'review_palate', 'review_taste', 'beer_name', 'beer_abv',
#        'beer_beerid'],
#       dtype='object')

# %%
test = test.drop(['brewery_id', 'brewery_name', 'review_time', 'review_profilename', 
                  'beer_style', 'beer_abv','beer_beerid'], axis=1)

# %%
total_sums = test.review_overall.values + test.review_aroma.values + \
             test.review_appearance.values + test.review_palate + test.review_taste

# %%
% timeit test['combined'] = total_sums/5
# Out:
# 3.45 ms ± 29.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
beer_grouping = test.groupby(['beer_name']).mean()

# %%
test.groupby('beer_name').count().drop(['review_overall',
                                        'review_aroma', 
                                        'review_appearance', 
                                        'review_palate',
                                        'review_taste'], axis=1).rename({'combined':'count'})
# Out:
#                                                     combined
# beer_name
# ! (Old Ale)                                                1
# "100"                                                      5
# "100" Pale Ale                                             1
# "12"  Belgian Golden Strong Ale                            2
# "33" Export                                                3
# "4" Horse Oatmeal Stout                                    2
# "400" Ale                                                 18
# "50" Golden Anniversary Lager                              1
# "76" Anniversary Ale                                       3
# "76" Anniversary Ale With English Hops                     1
# "Alt"ered State                                            2
# "Best Of Both Worlds" Stout                                1
# "Cellar Reserve" Triple Gold                               1
# "Certifiably" Blonde Ale                                   1
# "Check-Mate" Cask Pilsner                                  1
# "Double Wrecked Wreck" IPA                                 2
# "Fade To Black" Porter                                     1
# "Great Satchmo" Stout                                      1
# "Hop Obama" Ale                                           28
# "Jessica & Brendan's" Bridal Ale                           6
# "Just One More" Scotch Ale                                 4
# "Little John's Myth" Robust Porter                         2
# "M"                                                        1
# "M"-perial Stout                                           1
# "Marnie" Gras Carnival Ale                                 3
# "Naughty Scot" Scotch Ale                                  4
# "Nein Toll Bier" German Alt                                1
# "Not Guilty" 1924 Deer Brand                               7
# "Not Your Bock" Maibock                                    1
# "O Smokey Night"                                           1
# ...                                                      ...
# Ørsted BeerDog                                             2
# Ørsted Gold                                                2
# Úlfur                                                      3
# Über Alt                                                  15
# Über Blonde                                                1
# Über Düber Pilsner                                         1
# Über Frog                                                  1
# Über Oktolager                                             3
# Über Pils                                                228
# Über Pilsner                                               1
# Über Schwarz                                               1
# Über Special Bitter                                        4
# Über Weisse                                               16
# ÜberFest Pilsner                                           4
# ÜberSun (Imperial Summer Wheat Beer)                     233
# Überschwein (Unfiltered Double Dry Hopped Hog H...        12
# Þorrabjór                                                  1
# à L'Agave Et Au Citron Vert                                2
# überPils                                                   7
# Černá Hora Modrá Luna                                      1
# Łask Žywe Niefiltrowane                                    1
# Łomża Niepasteryzowana                                     1
# Świąteczne                                                 1
# Švyturys Nefiltruotas Raw                                  3
# Žamberecký Kanec 14°                                      1
# Žamberecký Kanec Imperial Stout                           2
# Ω-naught (Omeganaught)                                     3
# “Chewy” Double IPA                                         1
# 横須賀ビアサケ (Yokosuka Biasake)                                 1
# 葉山ビール (Hayama Beer)                                        1
#
# [56857 rows x 1 columns]

# %%
beer_grouping = beer_grouping.merge(test.groupby('beer_name').count()
                                    .drop(['review_overall',
                                           'review_aroma', 
                                           'review_appearance', 
                                           'review_palate',
                                           'review_taste'], axis=1)
                                    .rename(columns = {'combined':'count'}), left_index=True, right_index=True)

# %%
beer_grouping['weighted'] =
# Out:
#                                                     review_overall  \
# beer_name
# ! (Old Ale)                                               4.000000
# "100"                                                     4.000000
# "100" Pale Ale                                            4.000000
# "12"  Belgian Golden Strong Ale                           4.000000
# "33" Export                                               3.000000
# "4" Horse Oatmeal Stout                                   4.000000
# "400" Ale                                                 3.333333
# "50" Golden Anniversary Lager                             4.000000
# "76" Anniversary Ale                                      4.000000
# "76" Anniversary Ale With English Hops                    4.000000
# "Alt"ered State                                           3.500000
# "Best Of Both Worlds" Stout                               5.000000
# "Cellar Reserve" Triple Gold                              4.000000
# "Certifiably" Blonde Ale                                  2.500000
# "Check-Mate" Cask Pilsner                                 3.500000
# "Double Wrecked Wreck" IPA                                4.000000
# "Fade To Black" Porter                                    4.000000
# "Great Satchmo" Stout                                     4.000000
# "Hop Obama" Ale                                           4.160714
# "Jessica & Brendan's" Bridal Ale                          2.916667
# "Just One More" Scotch Ale                                3.625000
# "Little John's Myth" Robust Porter                        4.250000
# "M"                                                       4.000000
# "M"-perial Stout                                          3.000000
# "Marnie" Gras Carnival Ale                                3.833333
# "Naughty Scot" Scotch Ale                                 4.000000
# "Nein Toll Bier" German Alt                               4.000000
# "Not Guilty" 1924 Deer Brand                              4.071429
# "Not Your Bock" Maibock                                   4.500000
# "O Smokey Night"                                          3.500000
# ...                                                            ...
# Ørsted BeerDog                                            4.000000
# Ørsted Gold                                               3.250000
# Úlfur                                                     4.333333
# Über Alt                                                  4.166667
# Über Blonde                                               4.500000
# Über Düber Pilsner                                        4.000000
# Über Frog                                                 3.500000
# Über Oktolager                                            3.666667
# Über Pils                                                 4.057018
# Über Pilsner                                              4.000000
# Über Schwarz                                              4.000000
# Über Special Bitter                                       4.000000
# Über Weisse                                               3.687500
# ÜberFest Pilsner                                          4.000000
# ÜberSun (Imperial Summer Wheat Beer)                      4.060086
# Überschwein (Unfiltered Double Dry Hopped Hog H...        3.625000
# Þorrabjór                                                 3.000000
# à L'Agave Et Au Citron Vert                               2.500000
# überPils                                                  3.857143
# Černá Hora Modrá Luna                                     2.500000
# Łask Žywe Niefiltrowane                                   3.000000
# Łomża Niepasteryzowana                                    3.500000
# Świąteczne                                                2.000000
# Švyturys Nefiltruotas Raw                                 3.000000
# Žamberecký Kanec 14°                                     3.500000
# Žamberecký Kanec Imperial Stout                          3.750000
# Ω-naught (Omeganaught)                                    4.166667
# “Chewy” Double IPA                                        2.500000
# 横須賀ビアサケ (Yokosuka Biasake)                                4.000000
# 葉山ビール (Hayama Beer)                                       4.000000
#
#                                                     review_aroma  \
# beer_name
# ! (Old Ale)                                             4.500000
# "100"                                                   4.000000
# "100" Pale Ale                                          4.000000
# "12"  Belgian Golden Strong Ale                         3.500000
# "33" Export                                             3.000000
# "4" Horse Oatmeal Stout                                 3.500000
# "400" Ale                                               3.833333
# "50" Golden Anniversary Lager                           3.500000
# "76" Anniversary Ale                                    4.166667
# "76" Anniversary Ale With English Hops                  4.000000
# "Alt"ered State                                         3.750000
# "Best Of Both Worlds" Stout                             4.500000
# "Cellar Reserve" Triple Gold                            4.000000
# "Certifiably" Blonde Ale                                4.000000
# "Check-Mate" Cask Pilsner                               3.500000
# "Double Wrecked Wreck" IPA                              3.750000
# "Fade To Black" Porter                                  4.000000
# "Great Satchmo" Stout                                   4.000000
# "Hop Obama" Ale                                         3.910714
# "Jessica & Brendan's" Bridal Ale                        2.583333
# "Just One More" Scotch Ale                              4.000000
# "Little John's Myth" Robust Porter                      4.250000
# "M"                                                     4.000000
# "M"-perial Stout                                        3.500000
# "Marnie" Gras Carnival Ale                              4.333333
# "Naughty Scot" Scotch Ale                               3.625000
# "Nein Toll Bier" German Alt                             4.000000
# "Not Guilty" 1924 Deer Brand                            3.785714
# "Not Your Bock" Maibock                                 4.500000
# "O Smokey Night"                                        4.000000
# ...                                                          ...
# Ørsted BeerDog                                          3.500000
# Ørsted Gold                                             3.250000
# Úlfur                                                   4.166667
# Über Alt                                                3.933333
# Über Blonde                                             4.000000
# Über Düber Pilsner                                      4.000000
# Über Frog                                               3.500000
# Über Oktolager                                          3.500000
# Über Pils                                               3.754386
# Über Pilsner                                            4.000000
# Über Schwarz                                            3.500000
# Über Special Bitter                                     3.625000
# Über Weisse                                             3.593750
# ÜberFest Pilsner                                        3.500000
# ÜberSun (Imperial Summer Wheat Beer)                    4.012876
# Überschwein (Unfiltered Double Dry Hopped Hog H...      4.000000
# Þorrabjór                                               3.500000
# à L'Agave Et Au Citron Vert                             2.000000
# überPils                                                3.500000
# Černá Hora Modrá Luna                                   4.000000
# Łask Žywe Niefiltrowane                                 3.000000
# Łomża Niepasteryzowana                                  3.500000
# Świąteczne                                              5.000000
# Švyturys Nefiltruotas Raw                               3.166667
# Žamberecký Kanec 14°                                   4.000000
# Žamberecký Kanec Imperial Stout                        4.500000
# Ω-naught (Omeganaught)                                  4.000000
# “Chewy” Double IPA                                      2.000000
# 横須賀ビアサケ (Yokosuka Biasake)                              3.500000
# 葉山ビール (Hayama Beer)                                     3.000000
#
#                                                     review_appearance  \
# beer_name
# ! (Old Ale)                                                  4.000000
# "100"                                                        4.000000
# "100" Pale Ale                                               3.500000
# "12"  Belgian Golden Strong Ale                              4.250000
# "33" Export                                                  3.000000
# "4" Horse Oatmeal Stout                                      4.000000
# "400" Ale                                                    3.916667
# "50" Golden Anniversary Lager                                5.000000
# "76" Anniversary Ale                                         3.666667
# "76" Anniversary Ale With English Hops                       3.500000
# "Alt"ered State                                              4.000000
# "Best Of Both Worlds" Stout                                  4.500000
# "Cellar Reserve" Triple Gold                                 4.000000
# "Certifiably" Blonde Ale                                     2.500000
# "Check-Mate" Cask Pilsner                                    3.500000
# "Double Wrecked Wreck" IPA                                   3.250000
# "Fade To Black" Porter                                       4.000000
# "Great Satchmo" Stout                                        4.000000
# "Hop Obama" Ale                                              4.071429
# "Jessica & Brendan's" Bridal Ale                             3.166667
# "Just One More" Scotch Ale                                   3.875000
# "Little John's Myth" Robust Porter                           4.000000
# "M"                                                          4.000000
# "M"-perial Stout                                             3.000000
# "Marnie" Gras Carnival Ale                                   3.666667
# "Naughty Scot" Scotch Ale                                    3.875000
# "Nein Toll Bier" German Alt                                  3.500000
# "Not Guilty" 1924 Deer Brand                                 3.642857
# "Not Your Bock" Maibock                                      4.000000
# "O Smokey Night"                                             4.000000
# ...                                                               ...
# Ørsted BeerDog                                               4.000000
# Ørsted Gold                                                  3.000000
# Úlfur                                                        4.333333
# Über Alt                                                     3.866667
# Über Blonde                                                  3.000000
# Über Düber Pilsner                                           4.500000
# Über Frog                                                    3.500000
# Über Oktolager                                               3.833333
# Über Pils                                                    3.925439
# Über Pilsner                                                 4.000000
# Über Schwarz                                                 4.000000
# Über Special Bitter                                          3.625000
# Über Weisse                                                  3.812500
# ÜberFest Pilsner                                             3.250000
# ÜberSun (Imperial Summer Wheat Beer)                         4.015021
# Überschwein (Unfiltered Double Dry Hopped Hog H...           4.000000
# Þorrabjór                                                    4.000000
# à L'Agave Et Au Citron Vert                                  2.500000
# überPils                                                     3.928571
# Černá Hora Modrá Luna                                        2.500000
# Łask Žywe Niefiltrowane                                      3.000000
# Łomża Niepasteryzowana                                       2.000000
# Świąteczne                                                   4.500000
# Švyturys Nefiltruotas Raw                                    2.833333
# Žamberecký Kanec 14°                                        4.500000
# Žamberecký Kanec Imperial Stout                             4.500000
# Ω-naught (Omeganaught)                                       4.000000
# “Chewy” Double IPA                                           4.000000
# 横須賀ビアサケ (Yokosuka Biasake)                                   3.000000
# 葉山ビール (Hayama Beer)                                          3.000000
#
#                                                     review_palate  \
# beer_name
# ! (Old Ale)                                              4.000000
# "100"                                                    4.000000
# "100" Pale Ale                                           4.000000
# "12"  Belgian Golden Strong Ale                          4.750000
# "33" Export                                              3.166667
# "4" Horse Oatmeal Stout                                  3.250000
# "400" Ale                                                3.750000
# "50" Golden Anniversary Lager                            3.500000
# "76" Anniversary Ale                                     4.000000
# "76" Anniversary Ale With English Hops                   4.000000
# "Alt"ered State                                          4.000000
# "Best Of Both Worlds" Stout                              3.500000
# "Cellar Reserve" Triple Gold                             4.500000
# "Certifiably" Blonde Ale                                 2.500000
# "Check-Mate" Cask Pilsner                                3.500000
# "Double Wrecked Wreck" IPA                               4.000000
# "Fade To Black" Porter                                   3.000000
# "Great Satchmo" Stout                                    4.000000
# "Hop Obama" Ale                                          3.982143
# "Jessica & Brendan's" Bridal Ale                         3.000000
# "Just One More" Scotch Ale                               3.875000
# "Little John's Myth" Robust Porter                       4.250000
# "M"                                                      4.000000
# "M"-perial Stout                                         3.000000
# "Marnie" Gras Carnival Ale                               4.000000
# "Naughty Scot" Scotch Ale                                3.875000
# "Nein Toll Bier" German Alt                              3.500000
# "Not Guilty" 1924 Deer Brand                             3.714286
# "Not Your Bock" Maibock                                  3.500000
# "O Smokey Night"                                         4.000000
# ...                                                           ...
# Ørsted BeerDog                                           3.500000
# Ørsted Gold                                              3.000000
# Úlfur                                                    4.666667
# Über Alt                                                 4.266667
# Über Blonde                                              3.500000
# Über Düber Pilsner                                       4.000000
# Über Frog                                                3.500000
# Über Oktolager                                           4.166667
# Über Pils                                                3.861842
# Über Pilsner                                             4.000000
# Über Schwarz                                             3.500000
# Über Special Bitter                                      3.750000
# Über Weisse                                              3.468750
# ÜberFest Pilsner                                         3.500000
# ÜberSun (Imperial Summer Wheat Beer)                     3.995708
# Überschwein (Unfiltered Double Dry Hopped Hog H...       3.791667
# Þorrabjór                                                3.500000
# à L'Agave Et Au Citron Vert                              2.500000
# überPils                                                 3.928571
# Černá Hora Modrá Luna                                    3.000000
# Łask Žywe Niefiltrowane                                  2.500000
# Łomża Niepasteryzowana                                   3.500000
# Świąteczne                                               3.000000
# Švyturys Nefiltruotas Raw                                3.166667
# Žamberecký Kanec 14°                                    3.500000
# Žamberecký Kanec Imperial Stout                         4.250000
# Ω-naught (Omeganaught)                                   3.500000
# “Chewy” Double IPA                                       3.500000
# 横須賀ビアサケ (Yokosuka Biasake)                               3.500000
# 葉山ビール (Hayama Beer)                                      3.500000
#
#                                                     review_taste  combined  \
# beer_name
# ! (Old Ale)                                             4.500000  4.200000
# "100"                                                   4.400000  4.080000
# "100" Pale Ale                                          4.000000  3.900000
# "12"  Belgian Golden Strong Ale                         4.500000  4.200000
# "33" Export                                             3.000000  3.033333
# "4" Horse Oatmeal Stout                                 3.250000  3.600000
# "400" Ale                                               3.444444  3.655556
# "50" Golden Anniversary Lager                           3.500000  3.900000
# "76" Anniversary Ale                                    4.166667  4.000000
# "76" Anniversary Ale With English Hops                  4.500000  4.000000
# "Alt"ered State                                         4.000000  3.850000
# "Best Of Both Worlds" Stout                             5.000000  4.500000
# "Cellar Reserve" Triple Gold                            4.500000  4.200000
# "Certifiably" Blonde Ale                                2.500000  2.800000
# "Check-Mate" Cask Pilsner                               3.500000  3.500000
# "Double Wrecked Wreck" IPA                              3.750000  3.750000
# "Fade To Black" Porter                                  4.000000  3.800000
# "Great Satchmo" Stout                                   4.000000  4.000000
# "Hop Obama" Ale                                         4.160714  4.057143
# "Jessica & Brendan's" Bridal Ale                        2.333333  2.800000
# "Just One More" Scotch Ale                              3.625000  3.800000
# "Little John's Myth" Robust Porter                      4.250000  4.200000
# "M"                                                     4.000000  4.000000
# "M"-perial Stout                                        4.000000  3.300000
# "Marnie" Gras Carnival Ale                              4.000000  3.966667
# "Naughty Scot" Scotch Ale                               3.875000  3.850000
# "Nein Toll Bier" German Alt                             3.000000  3.600000
# "Not Guilty" 1924 Deer Brand                            4.071429  3.857143
# "Not Your Bock" Maibock                                 4.500000  4.200000
# "O Smokey Night"                                        4.000000  3.900000
# ...                                                          ...       ...
# Ørsted BeerDog                                          3.750000  3.750000
# Ørsted Gold                                             3.250000  3.150000
# Úlfur                                                   4.333333  4.366667
# Über Alt                                                4.266667  4.100000
# Über Blonde                                             4.500000  3.900000
# Über Düber Pilsner                                      4.000000  4.100000
# Über Frog                                               3.500000  3.500000
# Über Oktolager                                          3.833333  3.800000
# Über Pils                                               3.910088  3.901754
# Über Pilsner                                            4.500000  4.100000
# Über Schwarz                                            4.000000  3.800000
# Über Special Bitter                                     3.750000  3.750000
# Über Weisse                                             3.687500  3.650000
# ÜberFest Pilsner                                        3.875000  3.625000
# ÜberSun (Imperial Summer Wheat Beer)                    4.070815  4.030901
# Überschwein (Unfiltered Double Dry Hopped Hog H...      3.875000  3.858333
# Þorrabjór                                               3.500000  3.500000
# à L'Agave Et Au Citron Vert                             2.000000  2.300000
# überPils                                                4.000000  3.842857
# Černá Hora Modrá Luna                                   3.000000  3.000000
# Łask Žywe Niefiltrowane                                 3.000000  2.900000
# Łomża Niepasteryzowana                                  3.000000  3.100000
# Świąteczne                                              2.000000  3.300000
# Švyturys Nefiltruotas Raw                               3.000000  3.033333
# Žamberecký Kanec 14°                                   3.500000  3.800000
# Žamberecký Kanec Imperial Stout                        4.000000  4.200000
# Ω-naught (Omeganaught)                                  3.500000  3.833333
# “Chewy” Double IPA                                      2.500000  2.900000
# 横須賀ビアサケ (Yokosuka Biasake)                              3.500000  3.500000
# 葉山ビール (Hayama Beer)                                     4.000000  3.500000
#
#                                                     count
# beer_name
# ! (Old Ale)                                             1
# "100"                                                   5
# "100" Pale Ale                                          1
# "12"  Belgian Golden Strong Ale                         2
# "33" Export                                             3
# "4" Horse Oatmeal Stout                                 2
# "400" Ale                                              18
# "50" Golden Anniversary Lager                           1
# "76" Anniversary Ale                                    3
# "76" Anniversary Ale With English Hops                  1
# "Alt"ered State                                         2
# "Best Of Both Worlds" Stout                             1
# "Cellar Reserve" Triple Gold                            1
# "Certifiably" Blonde Ale                                1
# "Check-Mate" Cask Pilsner                               1
# "Double Wrecked Wreck" IPA                              2
# "Fade To Black" Porter                                  1
# "Great Satchmo" Stout                                   1
# "Hop Obama" Ale                                        28
# "Jessica & Brendan's" Bridal Ale                        6
# "Just One More" Scotch Ale                              4
# "Little John's Myth" Robust Porter                      2
# "M"                                                     1
# "M"-perial Stout                                        1
# "Marnie" Gras Carnival Ale                              3
# "Naughty Scot" Scotch Ale                               4
# "Nein Toll Bier" German Alt                             1
# "Not Guilty" 1924 Deer Brand                            7
# "Not Your Bock" Maibock                                 1
# "O Smokey Night"                                        1
# ...                                                   ...
# Ørsted BeerDog                                          2
# Ørsted Gold                                             2
# Úlfur                                                   3
# Über Alt                                               15
# Über Blonde                                             1
# Über Düber Pilsner                                      1
# Über Frog                                               1
# Über Oktolager                                          3
# Über Pils                                             228
# Über Pilsner                                            1
# Über Schwarz                                            1
# Über Special Bitter                                     4
# Über Weisse                                            16
# ÜberFest Pilsner                                        4
# ÜberSun (Imperial Summer Wheat Beer)                  233
# Überschwein (Unfiltered Double Dry Hopped Hog H...     12
# Þorrabjór                                               1
# à L'Agave Et Au Citron Vert                             2
# überPils                                                7
# Černá Hora Modrá Luna                                   1
# Łask Žywe Niefiltrowane                                 1
# Łomża Niepasteryzowana                                  1
# Świąteczne                                              1
# Švyturys Nefiltruotas Raw                               3
# Žamberecký Kanec 14°                                   1
# Žamberecký Kanec Imperial Stout                        2
# Ω-naught (Omeganaught)                                  3
# “Chewy” Double IPA                                      1
# 横須賀ビアサケ (Yokosuka Biasake)                              1
# 葉山ビール (Hayama Beer)                                     1
#
# [56857 rows x 7 columns]

# %%
C = beer_comp['review_overall'].mean()
m = 3
q_ratings = beer_comp.copy().loc[beer_comp['total_reviews'] >= m]

# %%
def weighted_rating(df, m=m, C=C):
    
    #########################################
    # Calculates and returns a weighted rating for specific feature
    # m is minimum votes/ratings required to be listed
    # C is the mean rating/vote across the whole dataframe
    # R is average rating/votes of feature
    # v is number of ratings/votes of feature
    #########################################
    
    v = df['total_reviews']
    R = df['review_overall']
    
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)
