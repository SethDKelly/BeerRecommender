# %%
import pandas as pd
import numpy as np

# %%
# %load get_data.py
def get_data() :
    
    import pandas as pd
    
    csv_beer = pd.read_csv("/home/grimoire/Projects/BeerRatings/rating_update.csv")
    beer_ratings = pd.DataFrame(csv_beer)
    
    return beer_ratings

# %% [markdown]
# ## Section will be used to look at user ratings based on:
# * Specific beers
# * Specific styles

# %%
ratings = get_data()

# %%
ratings.keys()
# Out:
# Index(['brewery_id', 'brewery_name', 'review_time', 'review_overall',
#        'review_aroma', 'review_appearance', 'review_profilename', 'beer_style',
#        'review_palate', 'review_taste', 'beer_name', 'beer_abv',
#        'beer_beerid'],
#       dtype='object')

# %%
profile_beer_rating = ratings.drop(['brewery_id', 'brewery_name', 'review_time','beer_abv','beer_beerid'], axis=1)

# %%
line_sums = profile_beer_rating.review_overall.values + profile_beer_rating.review_aroma.values + \
             profile_beer_rating.review_appearance.values + profile_beer_rating.review_palate + profile_beer_rating.review_taste

# %%
profile_beer_rating['combined'] = line_sums / 5

# %%
profile_beer_rating = profile_beer_rating.drop(['review_overall', 'review_appearance', 'review_taste',
                                               'review_palate', 'review_aroma'], axis=1)

# %% [markdown]
# ## Total count of ratings by profilename

# %%
profile_RatingTotalCount = profile_beer_rating.groupby(['review_profilename']).count().drop(['beer_style','beer_name'], axis=1).rename(columns={'combined':'count'})

# %%
profile_RatingTotalCount.describe() # We'll use a Minimum of Ratings (MoR) of 3
# Out:
#               count
# count  33387.000000
# mean      47.511487
# std      182.599759
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%       16.000000
# max     5817.000000

# %% [markdown]
# ## Total count of ratings by review_profilename and beer_name

# %%
profile_CountofRatingbyBeer = profile_beer_rating.groupby(['review_profilename', 'beer_name']).count().drop('beer_style', axis=1).rename(columns={'combined':'count'})

# %%
profile_CountofRatingbyBeer.describe()
# Out:
#               count
# count  1.561405e+06
# mean   1.015922e+00
# std    1.598142e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    1.700000e+01

# %% [markdown]
# ## Total ratings by review_profilename and beer_style

# %%
profile_CountofRatingbyStyle = profile_beer_rating.groupby(['review_profilename', 'beer_style']).count().drop('beer_name', axis=1).rename(columns={'combined':'count'})

# %%
profile_CountofRatingbyStyle
# Out:
#                                                                 count
# review_profilename beer_style
# 0110x011           American Amber / Red Ale                         3
#                    American Barleywine                              4
#                    American Black Ale                               1
#                    American Blonde Ale                              1
#                    American Brown Ale                               1
#                    American IPA                                    13
#                    American Imperial IPA                           16
#                    American Imperial Pilsner                        1
#                    American Imperial Stout                         11
#                    American Pale Ale (APA)                          4
#                    American Porter                                  4
#                    American Strong Ale                              7
#                    American Wild Ale                               14
#                    Baltic Porter                                    1
#                    Belgian Dark Ale                                 1
#                    Belgian Fruit Lambic                             3
#                    Belgian Gueuze                                   2
#                    Belgian IPA                                      1
#                    Belgian Lambic                                   1
#                    Belgian Quadrupel (Quad)                         3
#                    Belgian Saison                                   3
#                    Belgian Strong Dark Ale                          6
#                    Belgian Strong Pale Ale                          1
#                    Belgian Tripel                                   1
#                    Belgian Witbier                                  3
#                    British Barleywine                               2
#                    English India Pale Ale (IPA)                     1
#                    English Oatmeal Stout                            1
#                    English Old Ale                                  3
#                    English Pale Ale                                 1
# ...                                                               ...
# zymurgy4all        Flanders Red Ale                                 1
#                    Fruit and Field Beer                             3
#                    German Dunkelweizen                              1
#                    German Hefeweizen                                2
#                    German Kristalweizen                             1
#                    German Pilsner                                   3
#                    German Rauchbier                                 1
#                    German Schwarzbier                               4
#                    Irish Dry Stout                                  3
#                    Irish Red Ale                                    2
#                    Pumpkin Beer                                     1
#                    Scotch Ale / Wee Heavy                           1
#                    Vienna Lager                                     4
#                    Winter Warmer                                    2
# zymurgywhiz        American Amber / Red Ale                         1
#                    American IPA                                     1
# zythus             Belgian Dubbel                                   1
#                    English Brown Ale                                1
#                    English Extra Special / Strong Bitter (ESB)      1
#                    English Porter                                   1
#                    European Pale Lager                              1
#                    Fruit and Field Beer                             1
#                    German Bock                                      1
#                    German Kellerbier / Zwickelbier                  1
# zyzygy             American Barleywine                              1
#                    Belgian Saison                                   1
#                    English Brown Ale                                1
#                    German Altbier                                   1
#                    Russian Imperial Stout                           1
# zzajjber           European Pale Lager                              1
#
# [401184 rows x 1 columns]

# %%
profile_CountofRatingbyStyle.describe()
# Out:
#                count
# count  401184.000000
# mean        3.953961
# std         8.076015
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max       482.000000

# %%
m = 3 # we set MoR to 3
profile_RatingTotalCount = profile_RatingTotalCount.loc[profile_RatingTotalCount['count'] >= m]

# %%
# Create a set of review_profilenames that have at least 3 ratings
profiles_ThreeMR = set(profile_RatingTotalCount.index)

# %%
all_profiles = set(profile_beer_rating.review_profilename.unique())

# %%
drop_profiles = all_profiles - profiles_ThreeMR

# %%
profile_beer_rating['review_profilename'] = profile_beer_rating['review_profilename'].astype('str')

# %%
profile_beer_rating.loc[profile_beer_rating.review_profilename == 'nan', :]
# Out:
#         review_profilename                                   beer_style  \
# 8869                   nan                      American Imperial Stout
# 22125                  nan                      American Imperial Stout
# 31822                  nan                                 American IPA
# 33500                  nan                      American Imperial Stout
# 33678                  nan                      American Imperial Stout
# 38761                  nan                            English Brown Ale
# 40690                  nan                                Baltic Porter
# 42887                  nan                               German Pilsner
# 50208                  nan  English Extra Special / Strong Bitter (ESB)
# 69141                  nan                       American Adjunct Lager
# 75816                  nan                                 American IPA
# 75913                  nan                                 American IPA
# 79217                  nan                          American Barleywine
# 83633                  nan                                 American IPA
# 97356                  nan                                 American IPA
# 111444                 nan                       Foreign / Export Stout
# 111474                 nan                        English Pale Mild Ale
# 111537                 nan                        English Dark Mild Ale
# 111652                 nan                           English Strong Ale
# 111840                 nan                             English Pale Ale
# 111926                 nan                             English Pale Ale
# 112280                 nan                             English Pale Ale
# 112706                 nan                       Foreign / Export Stout
# 127628                 nan  English Extra Special / Strong Bitter (ESB)
# 131568                 nan                               Belgian Saison
# 1443748                                           Jubelale       4.6
# 1460492                                        Roxy Rolles       4.5
# 1472886                                   Decennium Bocköl       3.6
# 1477957                              Paulaner Premium Pils       2.9
# 1479104                               Salvator Doppel Bock       3.7
# 1479417                  Paulaner Hefe-Weissbier Naturtrüb       3.7
# 1481620                        Paulaner Oktoberfest-Märzen       2.8
# 1488539                        Yuengling Traditional Lager       3.1
# 1500239                               St. Bernardus Abt 12       4.7
# 1505550                               St. Bernardus Tripel       4.6
# 1506058                Houblon Chouffe Dobbelen IPA Tripel       4.2
# 1506093                Houblon Chouffe Dobbelen IPA Tripel       3.9
# 1516259                       Dorothy Goodbody's Our Glass       3.5
# 1528139                     Brooklyn Black Chocolate Stout       4.5
# 1544092                                       HopDevil Ale       4.5
# 1545518                                       HopDevil Ale       3.6
# 1549751                                   Storm King Stout       3.7
# 1552058                                         Prima Pils       4.2
# 1555051                                         Hop Wallop       4.8
# 1555959                                         Hop Wallop       2.4
# 1572884                       Grand Ridge Brewers Pilsener       3.0
# 1572957                             Grand Ridge Supershine       3.5
# 1573003                         Grand Ridge Natural Blonde       3.3
# 1573028                        Grand Ridge Hatlifter Stout       3.5
# 1573069                         Grand Ridge Gippsland Gold       3.3
# 1573134                      Grand Ridge Yarra Valley Gold       3.6
# 1573157                              Grand Ridge Moonshine       2.9
# 1580683                                      Alaskan Amber       2.9
# 1580902                                      Alaskan Amber       2.3
#
# [348 rows x 4 columns]

# %%
profile_beer_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 4 columns):
# review_profilename    1586614 non-null object
# beer_style            1586614 non-null object
# beer_name             1586614 non-null object
# combined              1586614 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 48.4+ MB

# %%
#profile_beer_rating
gb = profile_beer_rating.set_index(['review_profilename', 'beer_style']).sort_index()

# %%
gb.drop(drop_profiles, axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-c7fb44780649> in <module>()
# ----> 1 gb.drop(drop_profiles, axis=0)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2575                 indexer = ~axis.get_level_values(level).isin(labels)
#    2576             else:
# -> 2577                 indexer = ~axis.isin(labels)
#    2578
#    2579             slicer = [slice(None)] * self.ndim
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in isin(self, values, level)
#    2768         if level is None:
#    2769             values = MultiIndex.from_tuples(values,
# -> 2770                                             names=self.names).values
#    2771             return algos.isin(self.values, values)
#    2772         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in from_tuples(cls, tuples, sortorder, names)
#    1193                 tuples = tuples._values
#    1194
# -> 1195             arrays = list(lib.tuples_to_object_array(tuples).T)
#    1196         elif isinstance(tuples, list):
#    1197             arrays = list(lib.to_object_array_tuples(tuples).T)
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.tuples_to_object_array()
#
# TypeError: Expected tuple, got str

# %% [markdown]
# # finish creating/merging counts of

# %%
C = profile_beer_rating['combined'].mean()
m = 3
profile_RatingTotalCount = profile_RatingTotalCount.loc[profile_RatingTotalCount['count'] >= m]

# %%
def weighted_rating(df, m=m, C=C):
    
    #########################################
    # Calculates and returns a weighted rating for specific feature
    # m is minimum votes/ratings required to be listed
    # C is the mean rating/vote across the whole dataframe
    # R is average rating/votes of feature
    # v is number of ratings/votes of feature
    #########################################
    
    v = df['count']
    R = df['review_overall']
    
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_ratings['weighted_overall'] = q_ratings.apply(weighted_rating, axis=1)
