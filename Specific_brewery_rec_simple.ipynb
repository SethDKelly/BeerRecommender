# %%
import pandas as pd
import numpy as np

# %%
comp_csv = pd.read_csv('/home/grimoire/Projects/BeerRatings/comparison_brewery.csv')
brewery_comp = pd.DataFrame(comp_csv)

# %%
brewery_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5742 entries, 0 to 5741
# Data columns (total 7 columns):
# brewery_name             5742 non-null object
# review_overall           5742 non-null float64
# review_taste             5742 non-null float64
# review_appearance        5742 non-null float64
# review_palate            5742 non-null float64
# review_aroma             5742 non-null float64
# brewery_rating_counts    5742 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 314.1+ KB

# %%
brewery_comp['brewery_rating_counts'].describe()
# Out:
# count     5742.000000
# mean       276.314699
# std       1500.440673
# min          1.000000
# 25%          3.000000
# 50%         14.000000
# 75%         73.000000
# max      39444.000000
# Name: brewery_rating_counts, dtype: float64

# %%
C = brewery_comp['review_overall'].mean()

# %%
m = 14
q_ratings = brewery_comp.copy().loc[brewery_comp['brewery_rating_counts'] >= m]

# %% [raw]
# Using new apply functionality, this should be factored into a seperate part
# Keeping for prototyping
#
# def weighted_rating(df, m=0, C=0, v_col='totals', r_col='overall'):
#
#     #########################################
#     # Calculates and returns a weighted rating for specific feature
#     # m is minimum votes/ratings required to be listed
#     # C is the mean rating/vote across the whole dataframe
#     # R is average rating/votes of feature
#     # v is number of ratings/votes of feature
#     #########################################
#
#     v = df[v_col]
#     R = df[r_col]
#
#     # Calculation based on the IMDB formula
#     return (v/(v+m) * R) + (m/(m+v) * C)

# %%
def weighted_rating(df, m=m, C=C):
    
    #########################################
    # Calculates and returns a weighted rating for specific feature
    # m is minimum votes/ratings required to be listed
    # C is the mean rating/vote across the whole dataframe
    # R is average rating/votes of feature
    # v is number of ratings/votes of feature
    #########################################
    
    v = df['brewery_rating_counts']
    R = df['review_overall']
    
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_ratings['weighted_overall'] = q_ratings.apply(weighted_rating, axis=1)

# %%
q_ratings = q_ratings.sort_values('weighted_overall', ascending=False)

# %%
q_ratings
# Out:
#                                            brewery_name  review_overall  \
# 5085                                      The Alchemist        4.582543
# 1342  Brouwerij Westvleteren (Sint-Sixtusabdij van W...        4.544996
# 4538                      Russian River Brewing Company        4.373884
# 4088            Peg's Cantina & Brewpub / Cycle Brewing        4.506329
# 3871                            Närke Kulturbryggeri AB        4.363208
# 3341                           Live Oak Brewing Company        4.313356
# 2707                             Hill Farmstead Brewery        4.297191
# 1292                           Brouwerij Drie Fonteinen        4.291966
# 360             Bayerische Staatsbrauerei Weihenstephan        4.287127
# 3033                         Kern River Brewing Company        4.290635
# 278                  Badische Staatsbrauerei Rothaus AG        4.357143
# 916                              Brasserie de Rochefort        4.267913
# 1889                               De Cam Geuzestekerij        4.320755
# 5003                              Surly Brewing Company        4.255302
# 5086                        The Alchemist Pub & Brewery        4.275538
# 1118                            Brauerei Zehendner GmbH        4.607143
# 3638                      Minneapolis Town Hall Brewery        4.244338
# 1473                              COAST Brewing Company        4.247688
# 3078                            Klosterbrauerei Andechs        4.253142
# 5260                       Timothy Taylor & Co. Limited        4.284722
# 4686                      Selin's Grove Brewing Company        4.226648
# 114                                 Alpine Beer Company        4.212759
# 1325                         Brouwerij St. Bernardus NV        4.208276
# 3446                                 Maine Beer Company        4.218215
# 5142                  The Funky Buddha Lounge & Brewery        4.232836
