# %% [markdown]
# # Prototyping and testing

# %%
import pandas as pd

# %% [markdown]
# ## Load in the Data

# %%
csv = pd.read_csv('/home/grimoire/Projects/BeerRatings/beer_description.csv')
description = pd.DataFrame(csv)

# %%
style_csv = pd.read_csv('/home/grimoire/Projects/BeerRatings/comparison_style.csv')
style = pd.DataFrame(style_csv)

# %% [markdown]
# ## Build sets from style columns for set-wise comparison operations

# %%
description_set = set(description['style'].values)
style_set = set(style['beer_style'].values)

# %% [markdown]
# ### Items in the sets that are present in both, require no further action

# %%
description_set & style_set # Present in both sets
# Out:
# {'American Adjunct Lager',
#  'American Amber / Red Ale',
#  'American Amber / Red Lager',
#  'American Barleywine',
#  'American Black Ale',
#  'American Blonde Ale',
#  'American Brown Ale',
#  'American Dark Wheat Ale',
#  'American IPA',
#  'American Malt Liquor',
#  'American Pale Ale (APA)',
#  'American Pale Wheat Ale',
#  'American Porter',
#  'American Stout',
#  'American Strong Ale',
#  'American Wild Ale',
#  'Baltic Porter',
#  'Belgian Dark Ale',
#  'Belgian IPA',
#  'Belgian Pale Ale',
#  'Belgian Strong Dark Ale',
#  'Belgian Strong Pale Ale',
#  'Bière de Champagne / Bière Brut',
#  'Braggot',
#  'California Common / Steam Beer',
#  'Chile Beer',
#  'English Bitter',
#  'English Brown Ale',
#  'English Dark Mild Ale',
#  'English India Pale Ale (IPA)',
#  'English Pale Ale',
#  'English Pale Mild Ale',
#  'English Porter',
#  'English Stout',
#  'English Strong Ale',
#  'Flanders Oud Bruin',
#  'Flanders Red Ale',
#  'Foreign / Export Stout',
#  'Irish Dry Stout',
#  'Irish Red Ale',
#  'Japanese Rice Lager',
#  'Low Alcohol Beer',
#  'Munich Dunkel Lager',
#  'Russian Imperial Stout',
#  'Rye Beer',
#  'Scotch Ale / Wee Heavy',
#  'Scottish Ale',
#  'Scottish Gruit / Ancient Herbed Ale',
#  'Vienna Lager',
#  'Winter Warmer'}

# %% [markdown]
# ### Data that is in the Description Set but not in the Style set

# %%
description_set - style_set # Only in Description data not in Style data
# Out:
# {'American Brett',
#  'American Brut IPA',
#  'American Cream Ale',
#  'American Imperial IPA',
#  'American Imperial Pilsner',
#  'American Imperial Porter',
#  'American Imperial Red Ale',
#  'American Imperial Stout',
#  'American Lager',
#  'American Light Lager',
#  'American Wheatwine Ale',
#  'Belgian Blonde Ale',
#  'Belgian Dubbel',
#  'Belgian Faro',
#  'Belgian Fruit Lambic',
#  'Belgian Gueuze',
#  'Belgian Lambic',
#  'Belgian Quadrupel (Quad)',
#  'Belgian Saison',
#  'Belgian Tripel',
#  'Belgian Witbier',
#  'Berliner Weisse',
#  'Bohemian Pilsener',
#  'British Barleywine',
#  'English Extra Special / Strong Bitter (ESB)',
#  'English Oatmeal Stout',
#  'English Old Ale',
#  'English Sweet / Milk Stout',
#  'European Dark Lager',
#  'European Export / Dortmunder',
#  'European Pale Lager',
#  'European Strong Lager',
#  'Finnish Sahti',
#  'French Bière de Garde',
#  'Fruit and Field Beer',
#  'German Altbier',
#  'German Bock',
#  'German Doppelbock',
#  'German Dunkelweizen',
#  'German Eisbock',
#  'German Hefeweizen',
#  'German Helles',
#  'German Kellerbier / Zwickelbier',
#  'German Kristalweizen',
#  'German Kölsch',
#  'German Maibock',
#  'German Märzen / Oktoberfest',
#  'German Pilsner',
#  'German Rauchbier',
#  'German Roggenbier',
#  'German Schwarzbier',
#  'German Weizenbock',
#  'Herb and Spice Beer',
#  'Japanese Happoshu',
#  'Leipzig Gose',
#  'New England IPA',
#  'Pumpkin Beer',
#  'Robust Porter',
#  'Russian Kvass',
#  'Smoke Beer',
#  'Smoke Porter'}

# %% [markdown]
# ### Data that is in the Style Set but not in the Description set

# %%
style_set - description_set # Only in Style data not in description
# Out:
# {'Altbier',
#  'American Double / Imperial IPA',
#  'American Double / Imperial Pilsner',
#  'American Double / Imperial Stout',
#  'American Pale Lager',
#  'Berliner Weissbier',
#  'Bière de Garde',
#  'Black & Tan',
#  'Bock',
#  'Cream Ale',
#  'Czech Pilsener',
#  'Doppelbock',
#  'Dortmunder / Export Lager',
#  'Dubbel',
#  'Dunkelweizen',
#  'Eisbock',
#  'English Barleywine',
#  'Euro Dark Lager',
#  'Euro Pale Lager',
#  'Euro Strong Lager',
#  'Extra Special / Strong Bitter (ESB)',
#  'Faro',
#  'Fruit / Vegetable Beer',
#  'German Pilsener',
#  'Gose',
#  'Gueuze',
#  'Happoshu',
#  'Hefeweizen',
#  'Herbed / Spiced Beer',
#  'Keller Bier / Zwickel Bier',
#  'Kristalweizen',
#  'Kvass',
#  'Kölsch',
#  'Lambic - Fruit',
#  'Lambic - Unblended',
#  'Light Lager',
#  'Maibock / Helles Bock',
#  'Milk / Sweet Stout',
#  'Munich Helles Lager',
#  'Märzen / Oktoberfest',
#  'Oatmeal Stout',
#  'Old Ale',
#  'Pumpkin Ale',
#  'Quadrupel (Quad)',
#  'Rauchbier',
#  'Roggenbier',
#  'Sahti',
#  'Saison / Farmhouse Ale',
#  'Schwarzbier',
#  'Smoked Beer',
#  'Tripel',
#  'Weizenbock',
#  'Wheatwine',
#  'Witbier'}

# %%
rating_csv = pd.read_csv('/home/grimoire/Projects/BeerRatings/beer_reviews.csv')
ratings = pd.DataFrame(rating_csv)

# %%
update = ratings.copy()

# %% [markdown]
# ### Works but there has to be a better way...

# %%
update['beer_style'].loc[update['beer_style'] == 'Altbier'] = 'German Altbier'
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 'American Imperial IPA'
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial Pilsner'] = 'American Imperial Pilsner'
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial Stout'] = 'American Imperial Stout'
update['beer_style'].loc[update['beer_style'] == 'American Pale Lager'] = 'American Lager'
update['beer_style'].loc[update['beer_style'] == 'Berliner Weissbier'] = 'Berliner Weisse'
update['beer_style'].loc[update['beer_style'] == 'Bière de Garde'] = 'French Bière de Garde'
update['beer_style'].loc[update['beer_style'] == 'Black & Tan'] = 'American Porter'
update['beer_style'].loc[update['beer_style'] == 'Bock'] = 'German Bock'
update['beer_style'].loc[update['beer_style'] == 'Cream Ale'] = 'American Cream Ale'
# update['beer_style'].loc[update['beer_style'] == 'Czech Pilsener'] = 'Bohemian Pilsener'
update['beer_style'].loc[update['beer_style'] == 'Doppelbock'] = 'German Doppelbock'
update['beer_style'].loc[update['beer_style'] == 'Dortmunder / Export Lager'] = 'European Export / Dortmunder'
update['beer_style'].loc[update['beer_style'] == 'Dubbel'] = 
update['beer_style'].loc[update['beer_style'] == 'Dunkelweizen'] = 
update['beer_style'].loc[update['beer_style'] == 'Eisbock'] = 
update['beer_style'].loc[update['beer_style'] == 'English Barleywine'] = 
update['beer_style'].loc[update['beer_style'] == 'Euro Dark Lager'] = 
update['beer_style'].loc[update['beer_style'] == 'Euro Pale Lager'] = 
update['beer_style'].loc[update['beer_style'] == 'Euro Strong Lager'] = 
update['beer_style'].loc[update['beer_style'] == 'Extra Special / Strong Bitter (ESB)'] = 
update['beer_style'].loc[update['beer_style'] == 'Faro'] = 
update['beer_style'].loc[update['beer_style'] == 'Fruit / Vegetable Beer'] = 
update['beer_style'].loc[update['beer_style'] == 'German Pilsener'] = 
update['beer_style'].loc[update['beer_style'] == 'Gose'] = 
update['beer_style'].loc[update['beer_style'] == 'Gueuze'] = 
update['beer_style'].loc[update['beer_style'] == 'Happoshu'] = 
update['beer_style'].loc[update['beer_style'] == 'Hefeweizen'] = 
update['beer_style'].loc[update['beer_style'] == 'Herbed / Spiced Beer'] = 
update['beer_style'].loc[update['beer_style'] == 'Keller Bier / Zwickel Bier'] = 
update['beer_style'].loc[update['beer_style'] == 'Kristalweizen'] = 
update['beer_style'].loc[update['beer_style'] == 'Kvass'] = 
update['beer_style'].loc[update['beer_style'] == 'Kölsch'] = 
update['beer_style'].loc[update['beer_style'] == 'Lambic - Fruit'] = 
update['beer_style'].loc[update['beer_style'] == 'Lambic - Unblended'] = 
update['beer_style'].loc[update['beer_style'] == 'Light Lager'] = 
update['beer_style'].loc[update['beer_style'] == 'Maibock / Helles Bock'] = 
update['beer_style'].loc[update['beer_style'] == 'Milk / Sweet Stout'] = 
update['beer_style'].loc[update['beer_style'] == 'Munich Helles Lager'] = 
update['beer_style'].loc[update['beer_style'] == 'Märzen / Oktoberfest'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] = 
update['beer_style'].loc[update['beer_style'] == 'American Double / Imperial IPA'] =
# Out:
# /home/grimoire/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
update.loc[update['beer_style'] == 'Black & Tan']
# Out:
#          brewery_id             brewery_name  review_time  review_overall  \
# 2500            421      Formosa Brewing Co.   1147537037             3.5
# 2501            421      Formosa Brewing Co.   1031638788             3.5
# 2502            421      Formosa Brewing Co.    997954109             3.0
# 5458          14879     Hoppin' Frog Brewery   1216588253             4.5
# 5761          14879     Hoppin' Frog Brewery   1242214833             4.0
# 5769          14879     Hoppin' Frog Brewery   1208537466             4.5
# 5770          14879     Hoppin' Frog Brewery   1208320720             4.0
# 5771          14879     Hoppin' Frog Brewery   1208222665             4.0
# 5772          14879     Hoppin' Frog Brewery   1208022694             4.5
# 5773          14879     Hoppin' Frog Brewery   1207095479             4.0
# 5774          14879     Hoppin' Frog Brewery   1205648476             4.5
# 5775          14879     Hoppin' Frog Brewery   1203662078             4.0
# 5776          14879     Hoppin' Frog Brewery   1203266015             4.0
# 5777          14879     Hoppin' Frog Brewery   1189306605             4.0
# 5778          14879     Hoppin' Frog Brewery   1232300839             4.5
# 5779          14879     Hoppin' Frog Brewery   1200509624             4.5
# 5780          14879     Hoppin' Frog Brewery   1199435340             3.5
# 5781          14879     Hoppin' Frog Brewery   1199398909             4.0
# 5782          14879     Hoppin' Frog Brewery   1195360970             4.0
# 5783          14879     Hoppin' Frog Brewery   1194031885             4.0
# 5784          14879     Hoppin' Frog Brewery   1191813383             4.5
# 5785          14879     Hoppin' Frog Brewery   1191777112             4.0
# 5786          14879     Hoppin' Frog Brewery   1190394596             4.0
# 5787          14879     Hoppin' Frog Brewery   1188696504             4.0
# 5788          14879     Hoppin' Frog Brewery   1186066347             3.5
# 5789          14879     Hoppin' Frog Brewery   1183855044             4.0
# 5790          14879     Hoppin' Frog Brewery   1183148025             4.5
# 5791          14879     Hoppin' Frog Brewery   1180223325             4.0
# 5792          14879     Hoppin' Frog Brewery   1179410168             4.5
# 5793          14879     Hoppin' Frog Brewery   1178415836             4.0
# ...             ...                      ...          ...             ...
# 1486875       23980       Yuengling Brewery    1301066925             3.0
# 1486876       23980       Yuengling Brewery    1300847825             2.5
# 1486877       23980       Yuengling Brewery    1300326439             2.5
# 1486878       23980       Yuengling Brewery    1300062425             4.0
# 1486879       23980       Yuengling Brewery    1298164490             3.5
# 1486880       23980       Yuengling Brewery    1297540370             4.0
# 1486881       23980       Yuengling Brewery    1297536375             2.5
# 1486882       23980       Yuengling Brewery    1297535365             2.5
# 1486883       23980       Yuengling Brewery    1297134450             3.0
# 1486884       23980       Yuengling Brewery    1297058981             4.5
# 1486885       23980       Yuengling Brewery    1296972531             3.5
# 1486886       23980       Yuengling Brewery    1296934915             3.5
# 1486887       23980       Yuengling Brewery    1296705590             2.0
# 1486888       23980       Yuengling Brewery    1296700689             4.5
# 1486889       23980       Yuengling Brewery    1296515775             4.0
# 1486890       23980       Yuengling Brewery    1296095810             4.0
# 1486891       23980       Yuengling Brewery    1295931955             3.0
# 1573006        1478  Grand Ridge Brewing Co.   1189590209             3.0
# 1573026        1478  Grand Ridge Brewing Co.   1023125265             3.5
# 1573084        1478  Grand Ridge Brewing Co.   1246406659             4.5
# 1573103        1478  Grand Ridge Brewing Co.   1303955680             3.5
# 1573104        1478  Grand Ridge Brewing Co.   1255062920             2.5
# 1573105        1478  Grand Ridge Brewing Co.   1141996429             4.5
# 1573106        1478  Grand Ridge Brewing Co.   1140397821             4.0
# 1573107        1478  Grand Ridge Brewing Co.   1110112882             4.5
# 1573108        1478  Grand Ridge Brewing Co.   1105959156             3.0
# 1573109        1478  Grand Ridge Brewing Co.   1087387262             4.0
# 1573110        1478  Grand Ridge Brewing Co.   1086516699             4.0
# 1573111        1478  Grand Ridge Brewing Co.   1081250409             3.0
# 1573112        1478  Grand Ridge Brewing Co.   1067650880             3.0
#
#          review_aroma  review_appearance review_profilename   beer_style  \
# 2500              4.0                4.0          Mebuzzard  Black & Tan
# 2501              3.5                4.0               proc  Black & Tan
# 2502              3.0                3.0              Brent  Black & Tan
# 5458              4.0                4.0      JoeyBeerBelly  Black & Tan
# 5761              3.5                3.5             bort11  Black & Tan
# 5769              4.0                4.0           Kegatron  Black & Tan
# 5770              5.0                4.0       hustlesworth  Black & Tan
# 5771              3.5                3.5         currysage1  Black & Tan
# 5772              4.0                4.0           HopDerek  Black & Tan
# 5773              4.0                4.5       srobertson59  Black & Tan
# 5774              4.5                4.0    brewdlyhooked13  Black & Tan
# 5775              4.0                3.5            boogles  Black & Tan
# 5776              4.0                4.5           chilidog  Black & Tan
# 5777              4.0                3.5     northyorksammy  Black & Tan
# 5778              4.0                4.0           tmoneyba  Black & Tan
# 5779              4.5                4.5         WVbeergeek  Black & Tan
# 5780              4.5                4.5      PBRstreetgang  Black & Tan
# 5781              4.5                5.0           ppoitras  Black & Tan
# 5782              4.0                3.5          cameraman  Black & Tan
# 5783              3.5                4.5          SPLITGRIN  Black & Tan
# 5784              4.0                4.0         brewcrew76  Black & Tan
# 5785              4.0                4.5             WesWes  Black & Tan
# 5786              4.0                4.0        TheBierBand  Black & Tan
# 5787              3.5                4.0    DarkerTheBetter  Black & Tan
# 5788              4.0                4.0           merlin48  Black & Tan
# 5789              4.0                4.0            akorsak  Black & Tan
# 5790              3.0                4.5             Vancer  Black & Tan
# 5791              4.0                4.5       bluejacket74  Black & Tan
# 5792              4.0                4.0      BuckeyeNation  Black & Tan
# 5793              4.0                4.5              jpm30  Black & Tan
# ...               ...                ...                ...          ...
# 1486875           3.0                3.0         generallee  Black & Tan
# 1486876           2.0                3.5             haazer  Black & Tan
# 1486877           3.0                4.0       angrybabboon  Black & Tan
# 1486878           4.0                3.5             DerekP  Black & Tan
# 1486879           4.5                4.0         JohnFatAss  Black & Tan
