# %%
import pandas as pd
import numpy as np

# %%
comp_beer_csv = pd.read_csv('/home/grimoire/Projects/BeerRatings/comparison_beer.csv')
beer_comp = pd.DataFrame(comp_beer_csv)

# %%
beer_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56857 entries, 0 to 56856
# Data columns (total 7 columns):
# beer_name            56857 non-null object
# review_overall       56857 non-null float64
# review_taste         56857 non-null float64
# review_appearance    56857 non-null float64
# review_palate        56857 non-null float64
# review_aroma         56857 non-null float64
# total_reviews        56857 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ MB

# %%
beer_comp['total_reviews'].describe()
# Out:
# count    56857.000000
# mean        27.899221
# std        122.167414
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          9.000000
# max       3289.000000
# Name: total_reviews, dtype: float64

# %% [markdown]
# To ameliorate any possibly accidental entries in the overall rating. Using an average of all the ratings helped to solve any issues that could have possibly arisen as a result of accidental ratings. This methodology also allowed for more flexibility in rating increments. Instead of .5 increments the Averaged has a full decimal range.

# %%
beer_comp['averaged'] = (beer_comp.review_appearance + \
                        beer_comp.review_aroma + \
                        beer_comp.review_palate + \
                        beer_comp.review_taste + \
                        beer_comp.review_overall) / 5

# %%
C = beer_comp['averaged'].mean()

# %%
print('The mean rating for beer is: ', C)
# Out:
# The mean rating for beer is:  3.6135706681114668

# %%
m = 3
q_ratings = beer_comp.copy().loc[beer_comp['total_reviews'] >= m]

# %% [raw]
# Using new apply functionality, this should be factored into a seperate part
# Keeping for prototyping
#
# def weighted_rating(df, m=0, C=0, v_col='totals', r_col='overall'):
#
#     #########################################
#     # Calculates and returns a weighted rating for specific feature
#     # m is minimum votes/ratings required to be listed
#     # C is the mean rating/vote across the whole dataframe
#     # R is average rating/votes of feature
#     # v is number of ratings/votes of feature
#     #########################################
#
#     v = df[v_col]
#     R = df[r_col]
#
#     # Calculation based on the IMDB formula
#     return (v/(v+m) * R) + (m/(m+v) * C)

# %%
def weighted_rating(df, m=m, C=C):
    
    #########################################
    # Calculates and returns a weighted rating for specific feature
    # m is minimum votes/ratings required to be listed
    # C is the mean rating/vote across the whole dataframe
    # R is average rating/votes of feature
    # v is number of ratings/votes of feature
    #########################################
    
    v = df['total_reviews']
    R = df['averaged']
    
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_ratings['weighted_averaged'] = q_ratings.apply(weighted_rating, axis=1)

# %%
q_ratings = q_ratings.sort_values('weighted_averaged', ascending=False)

# %%
q_ratings
# Out:
#                                             beer_name  review_overall  \
# 41268                                     Rare D.O.S.        4.848485
# 31374                      M Belgian-Style Barleywine        4.750000
# 3109               Armand'4 Oude Geuze Lente (Spring)        4.730769
# 39650                               Pliny The Younger        4.600000
# 51855                        Trappist Westvleteren 12        4.617925
# 53223                     Vanilla Bean Aged Dark Lord        4.476974
# 19339                     Founders CBS Imperial Stout        4.591052
# 10757                         Cantillon Blåbær Lambik        4.628205
# 15244                                     Dirty Horse        4.820513
# 41266                       Rare Bourbon County Stout        4.544177
# 15048         Deviation - Bottleworks 9th Anniversary        4.620536
# 1704   Alesmith Speedway Stout - Vanilla And Coconut         4.937500
# 27453                         Kaggen! Stormaktsporter        4.529762
# 39649                                 Pliny The Elder        4.590028
# 12473                                      Citra DIPA        4.630952
# 50464                                       The Abyss        4.450779
# 20485  Geuze Cuvée J&J (Joost En Jessie) Blauw (Blue)        4.633803
# 40039                       Portsmouth Kate The Great        4.546729
# 3111               Armand'4 Oude Geuze Zomer (Summer)        4.644444
# 19392         Founders KBS (Kentucky Breakfast Stout)        4.397516
# 53371                                     Veritas 004        4.626506
# 35975               Oak Aged Dark Lord Imperial Stout        4.302817
# 23097                                    Heady Topper        4.625800
# 51856                         Trappist Westvleteren 8        4.514144
# 25440                        Hunahpu's Imperial Stout        4.365967
# 24978                                  Hoppy Birthday        4.684615
# 20198                  Galaxy Imperial Single Hop IPA        4.592105
# 48740                                 Stormaktsporter        4.527027
# 53372                                     Veritas 005        4.846154
# 17094                                        El Gordo        4.857143
# ...                                               ...             ...
# 51576                                     Tooheys Red        1.750000
# 9897                                        Bud Extra        1.953125
# 16830                           Ed Hardy Premium Beer        1.825000
# 33763                            Mongoose Malt Liquor        1.187500
# 42730                                Rock Green Light        2.204082
# 9932                              Budweiser Select 55        2.226415
# 10168                                     Busch Light        2.446629
# 9929                                Budweiser Chelada        1.931159
# 45455                                         Sharp's        1.945946
# 9900                                        Bud Light        2.422043
# 34771                                   Natural Light        2.521617
# 46332                                   Sleeman Clear        2.013158
# 20401                                     Genuine ALE        1.472222
# 50283                                         Tequiza        1.945055
# 9899                                    Bud Ice Light        2.017857
# 17113                                       El Lapino        1.136364
# 32738                                    Meister Bräu        1.860000
# 20248                                    Game Day Ice        1.685185
# 33932                                   MoonShot Beer        1.421053
# 48488                            Stite Golden Pilsner        1.333333
# 32960                                  Michelob Ultra        2.159656
# 9901                                Bud Light Chelada        1.710526
# 16745                   Earthquake High Gravity Lager        1.612245
# 13615                Crazy Ed's Cave Creek Chili Beer        1.488764
# 11027                                    Carlton Cold        1.583333
# 13388                                    Corona Light        1.957602
# 48489                               Stite Light Lager        1.111111
# 15309                               Dixie White Moose        1.250000
# 39535                                        Pit Bull        1.153846
# 17877                                        Evil Eye        1.471154
#
#        review_taste  review_appearance  review_palate  review_aroma  \
# 41268      4.848485           4.469697       4.803030      4.757576
# 31374      4.857143           4.482143       4.803571      4.785714
# 3109       4.730769           4.523077       4.669231      4.715385
# 39650      4.724590           4.482787       4.612295      4.723770
# 51855      4.718553           4.454009       4.633255      4.583333
# 53223      4.710526           4.450658       4.674342      4.717105
# 19339      4.697017           4.457614       4.579278      4.558085
# 10757      4.628205           4.644231       4.493590      4.528846
# 15244      4.743590           4.423077       4.576923      4.615385
# 41266      4.767068           4.269076       4.594378      4.658635
# 15048      4.687500           4.370536       4.566964      4.598214
# 1704       4.937500           4.625000       4.937500      5.000000
# 27453      4.714286           4.428571       4.577381      4.607143
# 39649      4.630985           4.388603       4.451326      4.612188
# 12473      4.573413           4.369048       4.373016      4.690476
# 50464      4.588173           4.593484       4.513102      4.443343
# 20485      4.570423           4.471831       4.436620      4.577465
# 40039      4.616822           4.369159       4.525701      4.433411
# 3111       4.600000           4.466667       4.488889      4.544444
# 19392      4.626294           4.377070       4.479814      4.570393
# 53371      4.668675           4.253012       4.506024      4.548193
# 35975      4.591549           4.457746       4.605634      4.577465
# 23097      4.608742           4.163113       4.405117      4.660981
# 51856      4.553041           4.415842       4.495050      4.426450
# 25440      4.564103           4.587413       4.511655      4.369464
# 24978      4.546154           4.400000       4.361538      4.569231
# 20198      4.559211           4.368421       4.440789      4.559211
# 48740      4.635135           4.351351       4.554054      4.608108
# 53372      4.807692           4.461538       4.538462      4.653846
# 17094      4.857143           4.928571       4.642857      4.857143
# ...             ...                ...            ...           ...
# 51576      1.375000           2.125000       1.583333      1.541667
# 9897       1.964844           2.121094       2.039062      1.988281
# 16830      1.725000           2.325000       1.937500      1.787500
# 33763      1.312500           1.750000       1.437500      1.500000
# 42730      1.882653           2.076531       1.892857      1.846939
# 9932       1.778302           2.240566       1.867925      1.759434
# 10168      1.862360           1.936798       2.018258      1.747191
# 9929       2.007246           2.000000       1.971014      1.942029
# 45455      1.837838           2.067568       1.743243      1.743243
# 9900       1.828725           2.011521       1.948541      1.747312
# 34771      1.824248           1.843985       1.927632      1.686090
# 46332      1.526316           2.026316       1.723684      1.802632
# 20401      1.388889           2.138889       1.722222      1.583333
# 50283      1.736264           1.989011       1.862637      1.890110
# 9899       1.750000           1.910714       1.830357      1.705357
# 17113      1.318182           1.636364       1.409091      1.772727
# 32738      1.520000           1.900000       1.660000      1.620000
# 20248      1.462963           2.055556       1.851852      1.518519
# 33932      1.500000           1.947368       1.605263      1.657895
# 48488      1.361111           2.222222       1.500000      1.416667
# 32960      1.695029           1.827916       1.803059      1.684512
# 9901       1.833333           1.868421       1.824561      1.736842
# 16745      1.438776           2.163265       1.693878      1.744898
# 13615      1.735955           2.101124       1.722846      1.951311
# 11027      1.354167           1.979167       1.583333      1.479167
# 13388      1.660819           1.915205       1.815789      1.640351
# 48489      1.111111           1.222222       1.222222      1.222222
# 15309      1.343750           1.718750       1.375000      1.531250
# 39535      1.153846           1.846154       1.230769      1.346154
# 17877      1.355769           2.221154       1.682692      1.509615
#
#        total_reviews  averaged  weighted_averaged
# 41268             33  4.745455           4.651131
# 31374             28  4.735714           4.627120
# 3109              65  4.673846           4.627069
# 39650            610  4.628689           4.623721
# 51855           1272  4.601415           4.599091
# 53223            152  4.605921           4.586714
# 19339            637  4.576609           4.572095
# 10757            156  4.584615           4.566294
# 15244             39  4.635897           4.562874
# 41266            249  4.566667           4.555320
# 15048            112  4.568750           4.543832
# 1704               8  4.887500           4.540065
# 27453             84  4.571429           4.538399
# 39649           2527  4.534626           4.533534
# 12473            252  4.527381           4.516630
# 50464           1412  4.517776           4.515859
# 20485             71  4.538028           4.500550
# 40039            428  4.498364           4.492206
# 3111              45  4.548889           4.490432
# 19392           1930  4.490217           4.488857
# 53371             83  4.520482           4.488845
# 35975            142  4.507042           4.488557
# 23097            469  4.492751           4.487163
# 51856            707  4.480905           4.477240
# 25440            429  4.479720           4.473705
# 24978             65  4.512308           4.472658
# 20198             76  4.503947           4.470136
# 48740             37  4.535135           4.466018
# 53372             13  4.661538           4.465045
# 17094              7  4.828571           4.464071
# ...              ...       ...                ...
# 51576             12  1.675000           2.062714
# 9897             128  2.013281           2.049929
# 16830             40  1.920000           2.038156
# 33763              8  1.437500           2.030974
# 42730             98  1.980612           2.029116
# 9932             106  1.974528           2.019640
# 10168            356  2.002247           2.015712
# 9929             138  1.970290           2.005253
# 45455             37  1.867568           1.998518
# 9900            1302  1.991628           1.995357
# 34771            532  1.960714           1.969983
# 46332             38  1.818421           1.949773
# 20401             18  1.661111           1.940034
# 50283             91  1.884615           1.939795
# 9899              56  1.842857           1.932893
# 17113             11  1.454545           1.917194
# 32738             25  1.712000           1.915740
# 20248             27  1.714815           1.904690
# 33932             19  1.626316           1.897305
# 48488             18  1.566667           1.859082
# 32960            522  1.834034           1.844203
# 9901             114  1.794737           1.841374
# 16745             49  1.730612           1.839244
# 13615            267  1.800000           1.820151
# 11027             24  1.595833           1.820026
# 13388            342  1.797953           1.813741
# 48489              9  1.177778           1.786726
# 15309             16  1.443750           1.786353
# 39535             13  1.346154           1.771295
# 17877             52  1.648077           1.755286
#
# [29412 rows x 9 columns]
