# %%
import pandas as pd
import numpy as np

# %%
comp_csv = pd.read_csv('/home/grimoire/Projects/BeerRatings/comparison_style.csv')
style_comp = pd.DataFrame(comp_csv)

# %%
style_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
# beer_style           103 non-null object
# review_overall       103 non-null float64
# review_taste         103 non-null float64
# review_appearance    103 non-null float64
# review_palate        103 non-null float64
# review_aroma         103 non-null float64
# count                103 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 5.7+ KB

# %%
style_comp['count'].describe()
# Out:
# count       103.000000
# mean      15404.019417
# std       17918.355962
# min         241.000000
# 25%        4000.000000
# 50%       10130.000000
# 75%       19757.500000
# max      117586.000000
# Name: count, dtype: float64

# %%
C = style_comp['review_overall'].mean()

# %%
m = 241
q_ratings = style_comp.copy().loc[style_comp['count'] >= m]

# %% [raw]
# Using new apply functionality, this should be factored into a seperate part
# Keeping for prototyping
#
# def weighted_rating(df, m=0, C=0, v_col='totals', r_col='overall'):
#
#     #########################################
#     # Calculates and returns a weighted rating for specific feature
#     # m is minimum votes/ratings required to be listed
#     # C is the mean rating/vote across the whole dataframe
#     # R is average rating/votes of feature
#     # v is number of ratings/votes of feature
#     #########################################
#
#     v = df[v_col]
#     R = df[r_col]
#
#     # Calculation based on the IMDB formula
#     return (v/(v+m) * R) + (m/(m+v) * C)

# %%
def weighted_rating(df, m=m, C=C):
    
    #########################################
    # Calculates and returns a weighted rating for specific feature
    # m is minimum votes/ratings required to be listed
    # C is the mean rating/vote across the whole dataframe
    # R is average rating/votes of feature
    # v is number of ratings/votes of feature
    #########################################
    
    v = df['count']
    R = df['review_overall']
    
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_ratings['weighted_overall'] = q_ratings.apply(weighted_rating, axis=1)

# %%
q_ratings = q_ratings.sort_values('weighted_overall', ascending=False)

# %%
q_ratings
# Out:
#                               beer_style  review_overall  review_taste  \
# 22                     American Wild Ale        4.093262      4.149938
# 28                        Belgian Gueuze        4.086287      4.127143
# 32              Belgian Quadrupel (Quad)        4.071630      4.210909
# 12               American Imperial Stout        4.029820      4.187230
# 94                Russian Imperial Stout        4.023084      4.149569
# 84                     German Weizenbock        4.007969      4.077348
# 10                 American Imperial IPA        3.998017      4.091280
# 30                        Belgian Lambic        4.048923      4.124327
# 64                      Flanders Red Ale        3.992722      4.090636
# 96                              Rye Beer        3.981737      3.999901
# 9                           American IPA        3.965221      3.922363
# 33                        Belgian Saison        3.962564      3.932656
# 75       German Kellerbier / Zwickelbier        3.981088      3.841181
# 72                        German Eisbock        3.977094      4.211603
# 29                           Belgian IPA        3.958704      4.007858
# 23                         Baltic Porter        3.955410      4.033270
# 50                 English Oatmeal Stout        3.941692      3.928548
# 4                     American Black Ale        3.934475      3.971606
# 73                     German Hefeweizen        3.929626      3.796761
# 25                        Belgian Dubbel        3.921733      3.947005
# 54                        English Porter        3.917946      3.909866
# 36                        Belgian Tripel        3.914287      3.963054
# 34               Belgian Strong Dark Ale        3.913322      4.029250
# 90                          Leipzig Gose        3.965015      3.907434
# 51                       English Old Ale        3.899000      4.057131
# 3                    American Barleywine        3.896756      4.042633
# 63                    Flanders Oud Bruin        3.902503      3.959059
# 35               Belgian Strong Pale Ale        3.895602      3.943506
# 38                       Berliner Weisse        3.901151      3.812374
# 57            English Sweet / Milk Stout        3.892526      3.894501
# ..                                   ...             ...           ...
# 62                         Finnish Sahti        3.700283      3.805372
# 102                        Winter Warmer        3.703935      3.718600
# 87                         Irish Red Ale        3.689730      3.551923
# 99   Scottish Gruit / Ancient Herbed Ale        3.686841      3.745729
# 52                      English Pale Ale        3.686565      3.529591
# 53                 English Pale Mild Ale        3.657857      3.483571
# 41                               Braggot        3.652404      3.743750
# 39       Bière de Champagne / Bière Brut        3.648184      3.693117
# 8                American Dark Wheat Ale        3.643878      3.566327
# 69                           German Bock        3.647814      3.560115
# 17               American Pale Wheat Ale        3.646918      3.458870
# 26                          Belgian Faro        3.600164      3.628079
# 93                          Pumpkin Beer        3.619646      3.629582
# 7                     American Cream Ale        3.602277      3.426041
# 5                    American Blonde Ale        3.591741      3.399615
# 2             American Amber / Red Lager        3.564601      3.373590
# 95                         Russian Kvass        3.355219      3.331650
# 85                   Herb and Spice Beer        3.470930      3.529457
# 58                   European Dark Lager        3.412927      3.326498
# 67                  Fruit and Field Beer        3.415124      3.405260
# 13                        American Lager        3.408946      3.201835
# 88                     Japanese Happoshu        2.914938      2.655602
# 60                   European Pale Lager        3.202775      2.998307
# 89                   Japanese Rice Lager        3.119987      2.845408
# 44                            Chile Beer        3.113298      3.309711
# 0                 American Adjunct Lager        3.001659      2.683112
# 61                 European Strong Lager        2.862518      2.825441
# 91                      Low Alcohol Beer        2.578268      2.462948
# 15                  American Malt Liquor        2.678854      2.541146
# 14                  American Light Lager        2.698833      2.272133
#
#      review_appearance  review_palate  review_aroma   count  weighted_overall
# 22            4.005451       4.040632      4.126756   17794          4.088467
# 28            4.034864       4.046680      4.117574    6009          4.072720
# 32            4.117964       4.124986      4.132533   18086          4.067196
# 12            4.163633       4.098669      4.160665   50705          4.028422
# 94            4.210072       4.086922      4.076576   54129          4.021804
# 84            4.009297       3.990703      4.044677    9412          4.001139
# 10            4.078916       4.023128      4.097782   85977          3.997280
# 30            3.912478       3.964991      4.118043    1114          3.992988
# 64            4.001801       3.970888      4.044043    6664          3.983707
# 96            4.001530       3.923001      3.893830   10130          3.975991
# 9             3.968525       3.867476      3.894103  117586          3.964749
# 33            3.997522       3.895521      3.932036   31480          3.960830
# 75            3.841953       3.806638      3.680046    2591          3.960099
# 72            3.964514       4.113594      4.156778    2663          3.956956
# 29            4.075214       3.944551      3.979753   12471          3.954452
# 23            4.039535       3.942707      3.946379   11572          3.950901
# 50            4.012125       3.841223      3.853045   18145          3.938975
# 4             4.112922       3.910231      3.930456   11446          3.930350
# 73            3.828293       3.750197      3.761735   27908          3.927955
# 25            4.000000       3.880899      3.900390   19983          3.919502
# 54            3.935446       3.788661      3.841652   11200          3.914081
# 36            3.952915       3.913150      3.913974   30328          3.912869
# 34            4.008293       3.937485      3.972260   37743          3.912187
# 90            3.908163       3.892857      3.783528     686          3.905069
# 51            3.941985       3.945045      4.007277   14703          3.896346
# 3             4.036535       3.996521      4.019343   26728          3.895306
# 63            3.899800       3.856557      3.937437    4995          3.894767
# 35            3.961353       3.892966      3.911924   31490          3.894378
# 38            3.692662       3.783741      3.669353    3475          3.890339
# 57            3.960922       3.797661      3.832713   13166          3.889684
# ..                 ...            ...           ...     ...               ...
# 62            3.655985       3.727144      3.827992    1061          3.706605
# 102           3.844635       3.670539      3.707178   20661          3.704287
# 87            3.763869       3.543671      3.424971    7877          3.691057
# 99            3.647037       3.633406      3.741367    2751          3.690675
# 52            3.695881       3.538992      3.420626   23402          3.687053
# 53            3.545714       3.509286      3.392143     700          3.677470
# 41            3.768269       3.723077      3.759615    1040          3.667837
# 39            4.045889       3.792543      3.734704    1046          3.664335
# 8             3.671088       3.539796      3.499660    1470          3.656633
# 69            3.691837       3.522077      3.446652   11528          3.649588
# 17            3.545468       3.490002      3.404148   24204          3.647781
# 26            3.754516       3.645320      3.678982     609          3.638234
# 93            3.675402       3.555466      3.754469   15550          3.621398
# 7             3.512943       3.509342      3.288536    5138          3.608198
# 5             3.508879       3.432736      3.313296   12726          3.594393
# 2             3.527494       3.354795      3.213296    9311          3.568886
# 95            3.476431       3.200337      3.338384     297          3.525091
# 85            3.600223       3.508416      3.572265   10337          3.476933
# 58            3.594589       3.279042      3.268413    4657          3.428746
# 67            3.517985       3.395839      3.525560   33861          3.417380
# 13            3.291516       3.256127      3.053907    9099          3.417345
# 88            2.925311       2.740664      2.595436     241          3.324687
# 60            3.170025       3.062365      2.847072   18015          3.209794
# 89            2.996442       2.915589      2.650388    1546          3.202854
# 44            3.347113       3.268810      3.300087    2286          3.172536
# 0             2.788546       2.735471      2.480211   30749          3.007357
# 61            3.229442       2.968062      2.872430    2724          2.933389
# 91            2.917569       2.519151      2.463364    1201          2.771497
# 15            2.837834       2.653758      2.413885    3925          2.739918
# 14            2.429390       2.339774      2.170009   14311          2.715984
#
# [103 rows x 8 columns]

# %%
q_ratings[q_ratings.beer_style == 'Bohemian Pilsener']
# Out:
#            beer_style  review_overall  review_taste  review_appearance  \
# 40  Bohemian Pilsener        3.794662      3.603414           3.641052
#
#     review_palate  review_aroma  count  weighted_overall
# 40       3.606162       3.44427  12740          3.793544
