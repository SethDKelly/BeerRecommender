# %%
import pandas as pd
import numpy as np

# %%
comp_csv = pd.read_csv('/home/grimoire/Projects/BeerRatings/comparison_style.csv')
style_comp = pd.DataFrame(comp_csv)

# %%
style_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 7 columns):
# beer_style           104 non-null object
# review_overall       104 non-null float64
# review_taste         104 non-null float64
# review_appearance    104 non-null float64
# review_palate        104 non-null float64
# review_aroma         104 non-null float64
# count                104 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 5.8+ KB

# %%
style_comp['count'].describe()
# Out:
# count       104.000000
# mean      15255.903846
# std       17830.331881
# min         241.000000
# 25%        3952.750000
# 50%        9978.000000
# 75%       19644.750000
# max      117586.000000
# Name: count, dtype: float64

# %%
C = style_comp['review_overall'].mean()

# %%
m = 241
q_ratings = style_comp.copy().loc[style_comp['count'] >= m]

# %% [raw]
# Using new apply functionality, this should be factored into a seperate part
# Keeping for prototyping
#
# def weighted_rating(df, m=0, C=0, v_col='totals', r_col='overall'):
#
#     #########################################
#     # Calculates and returns a weighted rating for specific feature
#     # m is minimum votes/ratings required to be listed
#     # C is the mean rating/vote across the whole dataframe
#     # R is average rating/votes of feature
#     # v is number of ratings/votes of feature
#     #########################################
#
#     v = df[v_col]
#     R = df[r_col]
#
#     # Calculation based on the IMDB formula
#     return (v/(v+m) * R) + (m/(m+v) * C)

# %%
def weighted_rating(df, m=m, C=C):
    
    #########################################
    # Calculates and returns a weighted rating for specific feature
    # m is minimum votes/ratings required to be listed
    # C is the mean rating/vote across the whole dataframe
    # R is average rating/votes of feature
    # v is number of ratings/votes of feature
    #########################################
    
    v = df['count']
    R = df['review_overall']
    
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_ratings['weighted_overall'] = q_ratings.apply(weighted_rating, axis=1)

# %%
q_ratings = q_ratings.sort_values('weighted_overall', ascending=False)

# %%
q_ratings
# Out:
#                               beer_style  review_overall  review_taste  \
# 20                     American Wild Ale        4.093262      4.149938
# 63                                Gueuze        4.086287      4.127143
# 86                      Quadrupel (Quad)        4.071630      4.210909
# 11      American Double / Imperial Stout        4.029820      4.187230
# 89                Russian Imperial Stout        4.023084      4.149569
# 100                           Weizenbock        4.007969      4.077348
# 9         American Double / Imperial IPA        3.998017      4.091280
# 75                    Lambic - Unblended        4.048923      4.124327
# 58                      Flanders Red Ale        3.992722      4.090636
# 90                              Rye Beer        3.981737      3.999901
# 12                          American IPA        3.965221      3.922363
# 92                Saison / Farmhouse Ale        3.962564      3.932656
# 70            Keller Bier / Zwickel Bier        3.981088      3.841181
# 41                               Eisbock        3.977094      4.211603
# 23                           Belgian IPA        3.958704      4.007858
# 21                         Baltic Porter        3.955410      4.033270
# 83                         Oatmeal Stout        3.941692      3.928548
# 5                     American Black Ale        3.934475      3.971606
# 65                            Hefeweizen        3.929626      3.796761
# 39                                Dubbel        3.921733      3.947005
# 49                        English Porter        3.917946      3.909866
# 98                                Tripel        3.914287      3.963054
# 25               Belgian Strong Dark Ale        3.913322      4.029250
# 62                                  Gose        3.965015      3.907434
# 84                               Old Ale        3.899000      4.057131
# 4                    American Barleywine        3.896756      4.042633
# 17                       American Porter        3.895735      3.898053
# 57                    Flanders Oud Bruin        3.902503      3.959059
# 26               Belgian Strong Pale Ale        3.895602      3.943506
# 27                    Berliner Weissbier        3.901151      3.812374
# ..                                   ...             ...           ...
# 102                        Winter Warmer        3.703935      3.718600
# 68                         Irish Red Ale        3.689730      3.551923
# 96   Scottish Gruit / Ancient Herbed Ale        3.686841      3.745729
# 47                      English Pale Ale        3.686565      3.529591
# 48                 English Pale Mild Ale        3.657857      3.483571
# 32                               Braggot        3.652404      3.743750
# 28       Bière de Champagne / Bière Brut        3.648184      3.693117
# 8                American Dark Wheat Ale        3.643878      3.566327
# 31                                  Bock        3.647814      3.560115
# 16               American Pale Wheat Ale        3.646918      3.458870
# 56                                  Faro        3.600164      3.628079
# 85                           Pumpkin Ale        3.619646      3.629582
# 35                             Cream Ale        3.602277      3.426041
# 6                    American Blonde Ale        3.591741      3.399615
# 3             American Amber / Red Lager        3.564601      3.373590
# 72                                 Kvass        3.355219      3.331650
# 30                           Black & Tan        3.486853      3.354962
# 66                  Herbed / Spiced Beer        3.470930      3.529457
# 52                       Euro Dark Lager        3.412927      3.326498
# 60                Fruit / Vegetable Beer        3.415124      3.405260
# 15                   American Pale Lager        3.408946      3.201835
# 64                              Happoshu        2.914938      2.655602
# 53                       Euro Pale Lager        3.202775      2.998307
# 69                   Japanese Rice Lager        3.119987      2.845408
# 34                            Chile Beer        3.113298      3.309711
# 1                 American Adjunct Lager        3.001659      2.683112
# 54                     Euro Strong Lager        2.862518      2.825441
# 77                      Low Alcohol Beer        2.578268      2.462948
# 13                  American Malt Liquor        2.678854      2.541146
# 76                           Light Lager        2.698833      2.272133
#
#      review_appearance  review_palate  review_aroma   count  weighted_overall
# 20            4.005451       4.040632      4.126756   17794          4.088437
# 63            4.034864       4.046680      4.117574    6009          4.072635
# 86            4.117964       4.124986      4.132533   18086          4.067167
# 11            4.163633       4.098669      4.160665   50705          4.028412
# 89            4.210072       4.086922      4.076576   54129          4.021795
# 100           4.009297       3.990703      4.044677    9412          4.001084
# 9             4.078916       4.023128      4.097782   85977          3.997274
# 75            3.912478       3.964991      4.118043    1114          3.992596
# 58            4.001801       3.970888      4.044043    6664          3.983630
# 90            4.001530       3.923001      3.893830   10130          3.975939
# 12            3.968525       3.867476      3.894103  117586          3.964745
# 92            3.997522       3.895521      3.932036   31480          3.960814
# 70            3.841953       3.806638      3.680046    2591          3.959911
# 41            3.964514       4.113594      4.156778    2663          3.956773
# 23            4.075214       3.944551      3.979753   12471          3.954411
# 21            4.039535       3.942707      3.946379   11572          3.950856
# 83            4.012125       3.841223      3.853045   18145          3.938946
# 5             4.112922       3.910231      3.930456   11446          3.930304
# 65            3.828293       3.750197      3.761735   27908          3.927936
# 39            4.000000       3.880899      3.900390   19983          3.919475
# 49            3.935446       3.788661      3.841652   11200          3.914034
# 98            3.952915       3.913150      3.913974   30328          3.912852
# 25            4.008293       3.937485      3.972260   37743          3.912173
# 62            3.908163       3.892857      3.783528     686          3.904496
# 84            3.941985       3.945045      4.007277   14703          3.896311
# 4             4.036535       3.996521      4.019343   26728          3.895286
# 17            3.957396       3.784446      3.836470   50477          3.894958
# 57            3.899800       3.856557      3.937437    4995          3.894665
# 26            3.961353       3.892966      3.911924   31490          3.894361
# 27            3.692662       3.783741      3.669353    3475          3.890196
# ..                 ...            ...           ...     ...               ...
# 102           3.844635       3.670539      3.707178   20661          3.704261
# 68            3.763869       3.543671      3.424971    7877          3.690991
# 96            3.647037       3.633406      3.741367    2751          3.690497
# 47            3.695881       3.538992      3.420626   23402          3.687031
# 48            3.545714       3.509286      3.392143     700          3.676905
# 32            3.768269       3.723077      3.759615    1040          3.667422
# 28            4.045889       3.792543      3.734704    1046          3.663922
# 8             3.671088       3.539796      3.499660    1470          3.656322
# 31            3.691837       3.522077      3.446652   11528          3.649543
# 16            3.545468       3.490002      3.404148   24204          3.647759
# 56            3.754516       3.645320      3.678982     609          3.637609
# 85            3.675402       3.555466      3.754469   15550          3.621365
# 35            3.512943       3.509342      3.288536    5138          3.608100
# 6             3.508879       3.432736      3.313296   12726          3.594352
# 3             3.527494       3.354795      3.213296    9311          3.568830
# 72            3.476431       3.200337      3.338384     297          3.524104
# 30            3.626166       3.298346      3.271416    2358          3.509607
# 66            3.600223       3.508416      3.572265   10337          3.476883
# 52            3.594589       3.279042      3.268413    4657          3.428638
# 60            3.517985       3.395839      3.525560   33861          3.417365
# 15            3.291516       3.256127      3.053907    9099          3.417288
# 64            2.925311       2.740664      2.595436     241          3.323585
# 53            3.170025       3.062365      2.847072   18015          3.209765
# 69            2.996442       2.915589      2.650388    1546          3.202556
# 34            3.347113       3.268810      3.300087    2286          3.172326
# 1             2.788546       2.735471      2.480211   30749          3.007340
# 54            3.229442       2.968062      2.872430    2724          2.933210
# 77            2.917569       2.519151      2.463364    1201          2.771129
# 13            2.837834       2.653758      2.413885    3925          2.739791
# 76            2.429390       2.339774      2.170009   14311          2.715947
#
# [104 rows x 8 columns]
